# %% [markdown]
# # SUMMER ANALYTICS 2024

# %% [markdown]
# # Week-1 Assignment

# %% [markdown]
# ![493179.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Data Grand Prix!**

# %% [markdown]
# **Welcome to your first assignment of Summer Analytics 2025! We hope you are excited to implement and test everything you have learnt up until now. The dataset which you'll use includes information about cars.**
#
# **We've got an interesting set of questions for you to get a basic understanding of pandas and data visualization libraries. GOOD LUCK!**
#
#
# ***Let's get started with importing numpy, pandas, seaborn and matplotlib!***
#
# Note - matplotlib should be imported with the command :
#
#  `import matplotlib.pyplot as plt`

# %% [markdown]
# ![image.avif](data:image/avif;base64,...)

# %% [markdown]
# **So lets get started!! Buckle up your belts for this exciting ride!!**

# %% [markdown]
# ### 1) Start by importing all important libraries
# For eg, "import numpy as np"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 2) Read the csv file and assign it to a variable .

# %%
#your code here
df=pd.read_csv('Cars.csv')

# %% [markdown]
# ### 3) Display shape of dataframe
# Expected Output - (398, 9)

# %%
#your code here
df.shape
# Out:
# (398, 9)

# %% [markdown]
# ### 4) Print all columns of dataframe
# Return an array containing names of all the columns.

# %%
#your code here
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# 1            70     usa          buick skylark 320
# 2            70     usa         plymouth satellite
# 3            70     usa              amc rebel sst
# 4            70     usa                ford torino
# ..          ...     ...                        ...
# 393          82     usa            ford mustang gl
# 394          82  europe                  vw pickup
# 395          82     usa              dodge rampage
# 396          82     usa                ford ranger
# 397          82     usa                 chevy s-10
#
# [398 rows x 9 columns]

# %% [markdown]
# ### 6) Set the 'name' column as the index of dataframe

# %%
#your code here
df.set_index('name')
# Out:
#                             mpg  cylinders  displacement  horsepower  weight  \
# name
# chevrolet chevelle malibu  18.0          8         307.0       130.0    3504
# buick skylark 320          15.0          8         350.0       165.0    3693
# plymouth satellite         18.0          8         318.0       150.0    3436
# amc rebel sst              16.0          8         304.0       150.0    3433
# ford torino                17.0          8         302.0       140.0    3449
# ...                         ...        ...           ...         ...     ...
# ford mustang gl            27.0          4         140.0        86.0    2790
# vw pickup                  44.0          4          97.0        52.0    2130
# dodge rampage              32.0          4         135.0        84.0    2295
# ford ranger                28.0          4         120.0        79.0    2625
# chevy s-10                 31.0          4         119.0        82.0    2720
#
#                            acceleration  model_year  origin
# name
# chevrolet chevelle malibu          12.0          70     usa
# buick skylark 320                  11.5          70     usa
# plymouth satellite                 11.0          70     usa
# amc rebel sst                      12.0          70     usa
# ford torino                        10.5          70     usa
# ...                                 ...         ...     ...
# ford mustang gl                    15.6          82     usa
# vw pickup                          24.6          82  europe
# dodge rampage                      11.6          82     usa
# ford ranger                        18.6          82     usa
# chevy s-10                         19.4          82     usa
#
# [398 rows x 8 columns]

# %% [markdown]
# ###  7) Print a list of all the unique mpg values

# %%
#your code here
print(df['mpg'].unique)
# Out:
# <bound method Series.unique of 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 398, dtype: float64>

# %% [markdown]
# ### 8) Create a column which contains the horsepower divided by weightas its metric and make this new column the index.

# %%
#your code here
df['new_col']=df['horsepower']/df['weight']
df.set_index('new_col')
# Out:
#            mpg  cylinders  displacement  horsepower  weight  acceleration  \
# new_col
# 0.037100  18.0          8         307.0       130.0    3504          12.0
# 0.044679  15.0          8         350.0       165.0    3693          11.5
# 0.043655  18.0          8         318.0       150.0    3436          11.0
# 0.043694  16.0          8         304.0       150.0    3433          12.0
# 0.040591  17.0          8         302.0       140.0    3449          10.5
# ...        ...        ...           ...         ...     ...           ...
# 0.030824  27.0          4         140.0        86.0    2790          15.6
# 0.024413  44.0          4          97.0        52.0    2130          24.6
# 0.036601  32.0          4         135.0        84.0    2295          11.6
# 0.030095  28.0          4         120.0        79.0    2625          18.6
# 0.030147  31.0          4         119.0        82.0    2720          19.4
#
#           model_year  origin                       name
# new_col
# 0.037100          70     usa  chevrolet chevelle malibu
# 0.044679          70     usa          buick skylark 320
# 0.043655          70     usa         plymouth satellite
# 0.043694          70     usa              amc rebel sst
# 0.040591          70     usa                ford torino
# ...              ...     ...                        ...
# 0.030824          82     usa            ford mustang gl
# 0.024413          82  europe                  vw pickup
# 0.036601          82     usa              dodge rampage
# 0.030095          82     usa                ford ranger
# 0.030147          82     usa                 chevy s-10
#
# [398 rows x 9 columns]

# %% [markdown]
# ![OIP (1).jpg](data:image/jpeg;base64,...)

# %% [markdown]
#  **Checkpoint!!
# Congratulations on making it this far. You are really keeping up in Data Grand Prix.
# Now starts the real race i.e. graded questions of the quiz.**

# %% [markdown]
# ## GRADED Questions (To be answered in the quiz)
# ### Try to retrieve some information from the data and answer the questions below . BEST OF LUCK !!

# %% [markdown]
# ### 1. What is name of car that has the highest horsepower?

# %%
#your code here
df[df['new_col']==df['new_col'].max()]
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 13  14.0          8         455.0       225.0    3086          10.0
#
#     model_year origin                     name  new_col
# 13          70    usa  buick estate wagon (sw)  0.07291

# %% [markdown]
# ### 2. How many cars have mpg ≥ 35?

# %%
#your code here

df[df['mpg'] >= 35].shape[0]
# Out:
# 36

# %% [markdown]
# ### 3. What is the most common origin for cars with horsepower > 100 and weight < 3000?

# %%
#your code here
df[(df['horsepower']>100) & (df['weight']<3000)]['origin'].value_counts()
# Out:
# origin
# usa       9
# europe    8
# japan     6
# Name: count, dtype: int64

# %% [markdown]
# ### 4. What is the mean acceleration of cars from Japan? (rounded to 2 decimals)

# %%
#your code here
df[df['origin']=='japan']['acceleration'].mean()
# Out:
# 16.17215189873418

# %% [markdown]
# ### 5. Which year had the highest average mpg?

# %%
#your code here
my=df.groupby('model_year')
my.mean(numeric_only=True).sort_values('mpg')
# Out:
#                   mpg  cylinders  displacement  horsepower       weight  \
# model_year
# 73          17.100000   6.375000    256.875000  130.475000  3419.025000
# 70          17.689655   6.758621    281.413793  147.827586  3372.793103
# 72          18.714286   5.821429    218.375000  120.178571  3237.714286
# 75          20.266667   5.600000    205.533333  101.066667  3176.800000
# 71          21.250000   5.571429    209.750000  107.037037  2995.428571
# 76          21.573529   5.647059    197.794118  101.117647  3078.735294
# 74          22.703704   5.259259    171.740741   94.230769  2877.925926
# 77          23.375000   5.464286    191.392857  105.071429  2997.357143
# 78          24.061111   5.361111    177.805556   99.694444  2861.805556
# 79          25.093103   5.827586    206.689655  101.206897  3055.344828
# 81          30.334483   4.620690    135.310345   81.035714  2522.931034
# 82          31.709677   4.193548    128.870968   81.466667  2453.548387
# 80          33.696552   4.137931    115.827586   77.481481  2436.655172
#
#             acceleration   new_col
# model_year
# 73             14.312500  0.037707
# 70             12.948276  0.042887
# 72             15.125000  0.036941
# 75             16.050000  0.032058
# 71             15.142857  0.035650
# 76             15.941176  0.032783
# 74             16.203704  0.033102
# 77             15.435714  0.035132
# 78             15.805556  0.034668
# 79             15.813793  0.033287
# 81             16.306897  0.032300
# 82             16.638710  0.033521
# 80             16.934483  0.031914

# %% [markdown]
# ## *Congratulations on coming this far! Since we were having so much fun playing with this dataset, let's move towards finish line by attempting some Ungraded questions!*
#
# ### **Note:** These questions are UNGRADED, and are given as an extra exercise.

# %% [markdown]
# ### Find the car (or cars) with the best ratio of horsepower to weight among all cars that also have above-median mpg.

# %%
#your code here
md=df['new_col'].median()
df[(df['new_col']==df['new_col'].max()) & (df['mpg'].median()>md)]
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 13  14.0          8         455.0       225.0    3086          10.0
#
#     model_year origin                     name  new_col
# 13          70    usa  buick estate wagon (sw)  0.07291

# %% [markdown]
# ### Design a multi-line plot using Matplotlib or Seaborn that shows the evolution of average mpg over the years, separately for each origin

# %%
g_data = df.groupby(['model_year','origin']).mean(numeric_only=True).reset_index()
g_data.head()
# Out:
#    model_year  origin        mpg  cylinders  displacement  horsepower  weight  \
# 0          70  europe  25.200000   4.000000    107.800000   86.200000  2309.2
# 1          70   japan  25.500000   4.000000    105.000000   91.500000  2251.0
# 2          70     usa  15.272727   7.636364    336.909091  166.954545  3716.5
# 3          71  europe  28.750000   4.000000     95.000000   74.000000  2024.0
# 4          71   japan  29.500000   4.000000     88.250000   79.250000  1936.0
#
#    acceleration   new_col
# 0     16.500000  0.037049
# 1     14.750000  0.040683
# 2     11.977273  0.044414
# 3     16.750000  0.036416
# 4     16.375000  0.040848

# %%
#your code here
sns.lineplot(y=g_data['mpg'] ,x=g_data['model_year'],hue=g_data['origin'])
# Out:
# <Axes: xlabel='model_year', ylabel='mpg'>

# %% [markdown]
# ### Create a Seaborn scatterplot (or PairGrid) where:
#
# X = horsepower
#
# Y = weight
#
# Color by: origin
#
# Size by: mpg
#
# Hue order = ['japan', 'europe', 'usa']
#
# Add meaningful plot titles and axis titles.

# %%
#your code here
df.head()
sns.scatterplot(x=df['horsepower'],y=df['weight'],hue=df['origin'],size=df['mpg'],hue_order=['japan', 'europe', 'usa'])
# Out:
# <Axes: xlabel='horsepower', ylabel='weight'>

# %% [markdown]
# ### We define a “consistent” car model as one that was produced over multiple years and had very low variation in mpg across those years (standard deviation < 1.0).
#
# Tasks:
#
# Identify car names that appear in more than one model_year.
#
# For each such name, compute the standard deviation of mpg across years.
#
# Return the car(s) with the lowest variation in mpg, among those with at least 2 appearances and std(mpg) < 1.0.
#
# Report the model name(s), number of appearances, and the average mpg.
#
# Bonus:
# Sort the result by number of appearances (descending), then mpg (descending).

# %%
name_years = df.groupby('name')['model_year'].nunique()
multi_year_names = name_years[name_years > 1].index
filtered_df = df[df['name'].isin(multi_year_names)]
grouped = filtered_df.groupby('name').agg(
    num_years=('model_year', 'nunique'),
    appearances=('name', 'count'),
    mpg_std=('mpg', 'std'),
    mpg_avg=('mpg', 'mean'))
consistent_cars = grouped[grouped['mpg_std'] < 1.0]
result = consistent_cars.sort_values(by=['appearances', 'mpg_avg'], ascending=[False, False])
result = result.reset_index()
result[['name', 'appearances', 'mpg_avg']]
# Out:
#                          name  appearances    mpg_avg
# 0            ford galaxie 500            3  14.333333
# 1           plymouth fury iii            3  14.333333
# 2         toyota corolla 1200            2  31.500000
# 3                   mazda 626            2  31.450000
# 4           volkswagen rabbit            2  29.250000
# 5                datsun pl510            2  27.000000
# 6                   saab 99le            2  24.500000
# 7              toyota mark ii            2  19.500000
# 8                 dodge aspen            2  18.850000
# 9   chevrolet chevelle malibu            2  17.500000
# 10           amc matador (sw)            2  14.500000
# 11      ford gran torino (sw)            2  13.500000
# 12                   ford ltd            2  13.500000

# %% [markdown]
# ![OIP.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Congratulations on completing the race. Kudos to you. Looking forward to meet you in next week.**
